# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:/Estiven/Datos/Proyectos/statistics-of-use-project/data/processed/app_usage_time_motorola.csv", 
                 delimiter=";",
                 index_col='date',
                 parse_dates=['date'])
df.head(2)
# Out:
#            Amazon Shopping Android System Biblioapp UdeA Bing Calculator  \
# date
# 2022-10-19              0s             4s             0s   0s      3m 1s
# 2022-10-20              0s             4s             0s   0s     1m 34s
#
#            Calculator_1 Calendar Call Management Camera Camera_2  ... Twitch  \
# date                                                              ...
# 2022-10-19           0s   1m 30s              0s     0s      15s  ...     0s
# 2022-10-20           0s       0s              0s     0s   8m 14s  ...     0s
#
#            Twitter tyba Upwork Talent VpnDialogs Wallpapers   WhatsApp  \
# date
# 2022-10-19      0s   0s            0s         0s         0s  1h 13m 6s
# 2022-10-20      0s   0s            0s         0s         0s  1h 1m 50s
#
#             YouTube YouTube Music Zoom
# date
# 2022-10-19       0s            0s   0s
# 2022-10-20  12m 59s            0s   0s
#
# [2 rows x 146 columns]

# %%
# Iterate over each column in the DataFrame
for col in df.columns:
    # Convert the column values to duration format
    df[col] = round(pd.to_timedelta(df[col]).dt.total_seconds() / 60, 2)

# Convert the DataFrame to duration data type
df
# Out:
#             Amazon Shopping  Android System  Biblioapp UdeA  Bing  Calculator  \
# date
# 2022-10-19             0.00            0.07             0.0   0.0        3.02
# 2022-10-20             0.00            0.07             0.0   0.0        1.57
# 2022-10-21             0.00            0.00             0.0   0.0        0.00
# 2022-10-22             0.00            0.15             0.0   0.0        0.00
# 2022-10-24             0.00            0.20             0.0   0.0        6.67
# ...                     ...             ...             ...   ...         ...
# 2023-05-24             0.12            0.17             0.0   0.0       14.73
# 2023-05-28             0.00            0.02             0.0   0.0        0.37
# 2023-05-29             0.00            0.10             0.0   0.0        0.00
# 2023-05-30             1.63            0.07             0.0   0.0        0.57
# 2023-06-05             0.00            0.18             0.0   0.0        2.15
#
# ...

# %%
pd.to_timedelta('1h 15m')
# Out:
# Timedelta('0 days 01:15:00')
